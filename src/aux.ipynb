# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

import copy
import datetime as dt
import requests
import pickle as pk
import gc
import sklearn
import math
# %matplotlib inline

# %%
arams=pd.read_csv("instance2/1025_hyp_tuning.log",header=None)




hyper_lgb_dic={0:'learning_rate',1:'num_leaves',2 : 'min_child_weight',3 :'subsample',4 :'min_split_gain',5 :'colsample_bytree',6 :'reg_lambda',7 :'reg_alpha',8 :"ndcg"}

# %%
arams
# Out:
#          0      1     2     3     4     5         6         7         8
# 0    0.225    326  17.0  0.75  0.95  0.70  0.791141  0.874739  0.545000
# 1    0.450    426   7.0  0.75  0.70  0.60  0.429840  0.462113  0.545232
# 2    0.500  20017  17.0  0.30  1.00  0.85  0.584668  0.527138  0.543843
# 3    0.325    176  16.0  0.55  0.80  1.00  0.387175  0.389505  0.545820
# 4    0.575  21358   5.0  0.40  0.70  0.85  0.452911  0.540321  0.543607
# 5    0.400   4197   4.0  0.60  0.90  0.95  0.842907  0.569408  0.545644
# 6    0.325   1004   3.0  0.55  0.65  0.60  0.363087  0.890645  0.546639
# 7    0.525    227   8.0  0.80  0.70  0.80  0.924223  0.632324  0.545260
# 8    0.600   1325   9.0  0.60  0.75  0.90  0.348656  0.985563  0.545064
# 9    0.375   1697   8.0  0.85  0.75  0.55  0.869896  0.807933  0.545761
# 10   0.325   2058   5.0  0.20  0.75  0.70  0.762463  0.596387  0.546365
# 11   0.700  20835  13.0  0.25  0.60  0.50  0.908634  0.335024  0.542232
# ...

# %%
arams.sort_values(8,ascending=False)
# Out:
#          0      1     2     3     4     5         6         7         8
# 69   0.050   4459   3.0  0.35  0.70  0.50  0.694102  0.741293  0.547807
# 137  0.050   3545   2.0  0.30  0.75  0.75  0.999890  0.884150  0.547796
# 65   0.050   3432   9.0  0.35  0.80  0.60  0.563405  0.792476  0.547789
# 150  0.050   3374   1.0  0.25  0.75  0.85  0.597019  0.868137  0.547738
# 147  0.050   3621   3.0  0.35  0.80  0.75  0.492706  0.827049  0.547716
# 123  0.050   2426   5.0  0.35  0.80  0.70  0.408972  0.625605  0.547706
# 89   0.050   3993   6.0  0.40  0.65  0.60  0.628571  0.685229  0.547688
# 148  0.050   4162   3.0  0.30  0.80  0.75  0.473576  0.825309  0.547674
# 68   0.050   5144   4.0  0.35  0.75  0.50  0.564866  0.757806  0.547649
# 67   0.050   3444   6.0  0.25  0.75  0.60  0.569048  0.800923  0.547641
# 133  0.075   2844   7.0  0.40  1.00  0.65  0.455986  0.764122  0.547631
# 154  0.075   3165   1.0  0.20  0.75  1.00  0.540472  0.907340  0.547607
# ...

# %%
math.log(4459)/math.log(2)
# Out:
# 12.122504484313906

# %%
plt.scatter(range(len(arams[8])),arams[8])

# %%
ord_params=sorted(trials.trials, key=lambda x: x['result']['los
# Out:
#   File "<ipython-input-5-39b1ce7ca2c2>", line 1
#     ord_params=sorted(trials.trials, key=lambda x: x['result']['los
#                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
arams=pd.read_csv("instance2/1026_hyp_tuning.log",header=None)



plt.scatter(range(len(arams[8])),arams[8])

# %%
arams.sort_values(8,ascending=False).head()
# Out:
#          0     1    2     3     4     5         6         7         8
# 275  0.075  4245  7.0  0.50  0.65  0.80  0.536214  0.647231  0.571613
# 73   0.050  4472  8.0  0.50  0.65  0.50  0.756192  0.896796  0.571445
# 87   0.050  4138  8.0  0.50  0.65  0.50  0.675592  0.924277  0.571436
# 174  0.050  6919  3.0  0.50  0.65  0.55  0.689992  0.802659  0.571411
# 69   0.050  8121  7.0  0.55  0.65  0.60  0.759131  0.962449  0.571393

# %%
aramelt=pd.melt(arams, value_vars =[0,3,4,5,6,7,8])

# %%
aramelt.head()
# Out:
#    variable  value
# 0         0  0.200
# 1         0  0.625
# 2         0  0.600
# 3         0  0.650
# 4         0  0.350

# %%
plt.figure(figsize=(16,12))

aramelt1=pd.melt(arams.sort_values(8,ascending=False).head(30), value_vars =[0,3,4,5,6,7,8]) 

#ax1 = sns.boxplot(x="variable", y="value", data=aramelt1,color="b",saturation=0.1)

aramelt2=pd.melt(arams.sort_values(8,ascending=False).tail(30), value_vars =[0,3,4,5,6,7,8]) 


#ax2 = sns.boxplot(ax=ax1,x="variable", y="value", data=aramelt2,color="r",saturation=0.1)


hyper_lgb_dic={0:'learning_rate',1:'num_leaves',2 : 'min_child_weight',3 :'subsample',4 :'min_split_gain',5 :'colsample_bytree',6 :'reg_lambda',7 :'reg_alpha',8 :"ndcg"}



aramelt1["type"]="best"

aramelt2["type"]="worst"
aramelt1.reset_index()
aramelt2.reset_index()



aramelt_t=pd.concat([aramelt1,aramelt2])

aramelt_t["variable"]=aramelt_t.variable.replace(hyper_lgb_dic)




sns.boxplot(x="variable", y="value", hue="type", data=aramelt_t, linewidth=2.5)

# %%
aramelt_t
# Out:
#           variable     value   type
# 0    learning_rate  0.050000   best
# 1    learning_rate  0.050000   best
# 2    learning_rate  0.050000   best
# 3    learning_rate  0.050000   best
# 4    learning_rate  0.050000   best
# 5    learning_rate  0.050000   best
# 6    learning_rate  0.075000   best
# 7    learning_rate  0.050000   best
# 8    learning_rate  0.075000   best
# 9    learning_rate  0.050000   best
# 10   learning_rate  0.050000   best
# 11   learning_rate  0.050000   best
# 12   learning_rate  0.075000   best
# 13   learning_rate  0.050000   best
# 14   learning_rate  0.050000   best
# 15   learning_rate  0.075000   best
# 16   learning_rate  0.050000   best
# 17   learning_rate  0.050000   best
# 18   learning_rate  0.050000   best
# 19   learning_rate  0.050000   best
# 20   learning_rate  0.050000   best
# 21   learning_rate  0.050000   best
# 22   learning_rate  0.075000   best
# 23   learning_rate  0.050000   best
# 24   learning_rate  0.075000   best
# ...

# %%
ax = sns.boxplot(x="day", y="total_bill", hue="time",
...                  data=tips, linewidth=2.5)
# Out:
#   File "<ipython-input-8-48560b7788e4>", line 3
#     ...                  data=tips, linewidth=2.5)
#                             ^
# SyntaxError: invalid syntax

# %%
spread = np.random.rand(50) * 100
center = np.ones(25) * 40
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
d2 = np.concatenate((spread, center, flier_high, flier_low))
data.shape = (-1, 1)
d2.shape = (-1, 1)
Copy to clipboard
Making a 2-D array only works if all the columns are the same length. If they are not, then use a list instead. This is actually more efficient because boxplot converts a 2-D array into a list of vectors internally anyway.

data = [data, d2, d2[::2,0]]
fig7, ax7 = plt.subplots()
ax7.set_title('Multiple Samples with Different sizes')
ax7.boxplot(data)

plt.show()
# Out:
#   File "<ipython-input-9-82546d9848f3>", line 8
#     Copy to clipboard
#           ^
# SyntaxError: invalid syntax

# %%
arams=pd.read_csv("instance3/3000_hyp_tuning.log",header=None)



plt.scatter(range(len(arams[8])),arams[8])

# %%
arams=pd.read_csv("instance4/3000_hyp_tuning .log",header=None)


fig, ax = plt.subplots()
ax.hlines(0.57, 0, len(arams),colors='k', linestyles='solid', label='baseline')

plt.scatter(range(len(arams[8])),arams[8],label="eval")
ax.legend()

plt.ylabel('NDCG')
plt.title('LGBM NDCG train buyers eval buyers')
plt.show()

# %%
plt.figure(figsize=(16,12))

aramelt1=pd.melt(arams.sort_values(8,ascending=False).head(30), value_vars =[0,3,4,5,6,7,8]) 

#ax1 = sns.boxplot(x="variable", y="value", data=aramelt1,color="b",saturation=0.1)

aramelt2=pd.melt(arams.sort_values(8,ascending=False).tail(30), value_vars =[0,3,4,5,6,7,8]) 


#ax2 = sns.boxplot(ax=ax1,x="variable", y="value", data=aramelt2,color="r",saturation=0.1)


hyper_lgb_dic={0:'learning_rate',1:'num_leaves',2 : 'min_child_weight',3 :'subsample',4 :'min_split_gain',5 :'colsample_bytree',6 :'reg_lambda',7 :'reg_alpha',8 :"ndcg"}



aramelt1["type"]="best"

aramelt2["type"]="worst"
aramelt1.reset_index()
aramelt2.reset_index()



aramelt_t=pd.concat([aramelt1,aramelt2])

aramelt_t["variable"]=aramelt_t.variable.replace(hyper_lgb_dic)




sns.boxplot(x="variable", y="value", hue="type", data=aramelt_t, linewidth=2.5,)

# %%
print(arams.sort_values(8,ascending=False).head(50).mean())

print(arams.sort_values(8,ascending=False).head(50).std())



print(arams.sort_values(8,ascending=False).tail(50).mean())

print(arams.sort_values(8,ascending=False).tail(50).std())
# Out:
# 0       0.056500
# 1    7343.180000
# 2       7.440000
# 3       0.701000
# 4       0.870000
# 5       0.682000
# 6       0.740615
# 7       0.508721
# 8       0.561770
# dtype: float64
# 0       0.012174
# 1    3042.534843
# 2       4.798639
# 3       0.169480
# 4       0.078246
# 5       0.113731
# 6       0.120520
# 7       0.151368
# 8       0.000581
# dtype: float64
# 0        0.526000
# 1    10479.080000
# 2        8.780000
# 3        0.705000
# 4        0.834000
# 5        0.685000
# 6        0.722311
# 7        0.530391
# 8        0.534913
# dtype: float64
# 0       0.112708
# 1    5760.919130
# 2       5.625344
# 3       0.204353
# 4       0.102738
# 5       0.118343
# 6       0.149164
# 7       0.159303
# 8       0.005575
# dtype: float64

# %%
arams=pd.read_csv("instance4/3001_hyp_tuning.log",header=None)



plt.scatter(range(len(arams[8])),arams[8])

# %%
arams=pd.read_csv("instance4/3002_hyp_tuning.log",header=None)



plt.scatter(range(len(arams[8])),arams[8])
