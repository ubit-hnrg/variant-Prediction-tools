# %%
# %matplotlib inline
from IPython.display import display, clear_output
import pandas as pd
import numpy as np
import time
import gc
import warnings
warnings.filterwarnings('ignore')
opath='~/clinvar_omim_by_GEN/'

# %%
clinvar_omim_AR_byGene=pd.read_csv(opath+'AR-clinvarOMIM.tsv',sep='\t')
clinvar_omim_AD_byGene=pd.read_csv(opath+'AD-clinvarOMIM.tsv',sep='\t')
clinvar_omim_BothModels_byGene=pd.read_csv(opath+'ADAR-clinvarOMIM.tsv',sep='\t')

# %%
clinvar_omim_AR_byGene.head(30)
# Out:
#                                                  Name   Gene(s)  \
# 0    NM_002645.3(PIK3C2A):c.(?_1-1)_4007+1_4008-1)del   PIK3C2A
# 1                      NG_050967.1:g.291668_510915del    EXOC6B
# 2                            RFC1, AAGGG(n) EXPANSION      RFC1
# 3                                 NM_172862.3:c.15del     FREM2
# 4            NM_005236.2(ERCC4):c.388+1164_792+795del     ERCC4
# 5                                     RTTN, ARG985GLY      RTTN
# 6                  NM_015909.3:c.(?_5028)_(5724_?)del      NBAS
# 7                          NM_006642.3:c.1069_1356del   SDCCAG8
# 8                                 NM_023343.1:c.55G>A  RNU4ATAC
# 9                           NM_000135.2:c.894_2641del     FANCA
# 10                          NM_000135.2:c.523_2601del     FANCA
# 11  NM_019042.4(PUS7):c.(1757+1_1758-1)_(1848+1_18...      PUS7
# 12         NM_001003722.1(GLE1):c.100-7_100-3delTCTCT      GLE1
# 13  POLR3A, IVS14, G-A, +22 (rs191875469) AND IVS2...    POLR3A
# ...

# %%
clinvar_recessive=pd.read_csv("/home/felipe/clinvar_result_recessive.txt",sep='\t')
clinvar_dominant=pd.read_csv("/home/felipe/clinvar_result_autosomal_dominant.txt",sep='\t')

# %%
clinvar_recessive.head()
# Out:
#                             Name Gene(s)  \
# 0               MYORG, ILE655THR   MYORG
# 1  NM_020702.5:c.782_783delinsTT   MYORG
# 2           NM_003754.2:c.694T>G   EIF3F
# 3         NM_032819.4:c.1062delG  ZNF341
# 4                   PRG4, EX1DEL    PRG4
#
#                                         Condition(s)  \
# 0  BASAL GANGLIA CALCIFICATION, IDIOPATHIC, 7, AU...
# 1  BASAL GANGLIA CALCIFICATION, IDIOPATHIC, 7, AU...
# 2  INTELLECTUAL DEVELOPMENTAL DISORDER, AUTOSOMAL...
# 3  HYPER-IgE RECURRENT INFECTION SYNDROME 3, AUTO...
# 4  Camptodactyly arthropathy coxa vara pericardit...
#
#      Clinical significance (Last reviewed)                   Review status  \
# 0   Pathogenic(Last reviewed: Feb 8, 2019)  no assertion criteria provided
# 1   Pathogenic(Last reviewed: Feb 8, 2019)  no assertion criteria provided
# 2  Pathogenic(Last reviewed: Jan 24, 2019)  no assertion criteria provided
# 3   Pathogenic(Last reviewed: Feb 4, 2019)  no assertion criteria provided
# ...

# %%
print(len(clinvar_omim_AR_byGene))
for df in [clinvar_recessive,clinvar_dominant]:
    print(sum(clinvar_omim_AR_byGene["VariationID"].isin(df.VariationID)))
    print(len(df))
# Out:
# 69809
# 16889
# 27227
# 1900
# 58713

# %% [markdown]
# De un total de 69809 imputadas hay 1900 que en clinvar dice que son dominantes...chequeemos mejor

# %%
possible_fails=clinvar_omim_AR_byGene[clinvar_omim_AR_byGene["VariationID"].isin(clinvar_dominant.VariationID)]

# %%
possible_fails.clinsig.isin(['Pathogenic','Likely pathogenic']).sum()
# Out:
# 148

# %% [markdown]
# #### solo 148 de estas variantes parecen patogenicas

# %%
possible_fails[possible_fails.clinsig.isin(['Pathogenic','Likely pathogenic'])]
# Out:
#                                                     Name  Gene(s)  \
# 69                                      15q15.3 deletion     STRC
# 70                NC_000009.11:g.71705804_71974823invdup     TJP2
# 597                               AMHR2, 1-BP DEL, 1692A    AMHR2
# 833                                      VPS13A, 8035G-A   VPS13A
# 1946          NM_000302.3(PLOD1):c.1533C>G (p.Tyr511Ter)    PLOD1
# 2775          NM_156039.3(CSF3R):c.1919C>A (p.Thr640Asn)    CSF3R
# 3244   NM_001128425.1(MUTYH):c.1437_1439delGGA (p.Glu...    MUTYH
# 3245       NM_001128425.1(MUTYH):c.1438G>T (p.Glu480Ter)    MUTYH
# 3269    NM_001128425.1(MUTYH):c.1356delA (p.Tyr453Ilefs)    MUTYH
# 3333       NM_001128425.1(MUTYH):c.1214C>T (p.Pro405Leu)    MUTYH
# 3343       NM_001128425.1(MUTYH):c.1171C>T (p.Gln391Ter)    MUTYH
# 3390       NM_001128425.1(MUTYH):c.1012C>T (p.Gln338Ter)    MUTYH
# 3421        NM_001128425.1(MUTYH):c.940C>T (p.Gln314Ter)    MUTYH
# ...

# %% [markdown]
# hay varias de estas con criterios de mucho peso habria que chequear bien que esta pasando con el cruce y si justo los genes en que caen estas no habria que transformarlos a herencia multiple

# %%
print("total dominant cruce")
print(len(clinvar_omim_AD_byGene))
for df in [clinvar_recessive,clinvar_dominant]:
    print(sum(clinvar_omim_AD_byGene["VariationID"].isin(df.VariationID)))
    print(len(df))
# Out:
# 76068
# 199
# 27227
# 15222
# 58713

# %%
possible_fails=clinvar_omim_AD_byGene[clinvar_omim_AD_byGene["VariationID"].isin(clinvar_recessive.VariationID)]

# %%
possible_fails.clinsig.isin(['Pathogenic','Likely pathogenic']).sum()
# Out:
# 107

# %% [markdown]
# solo 107 de estas variantes parecen patogenicas

# %%
possible_fails[possible_fails.clinsig.isin(['Pathogenic','Likely pathogenic'])]
# Out:
#                                                     Name  Gene(s)  \
# 741                                CRX, 2-BP DEL, GLU168      CRX
# 751                                         OPTN, EX5DEL     OPTN
# 830                              FOXL2, 15-BP DUP, NT684    FOXL2
# 1389        NM_005026.4(PIK3CD):c.3061G>A (p.Glu1021Lys)   PIK3CD
# 1976             NM_003000.2(SDHB):c.268C>T (p.Arg90Ter)     SDHB
# 2008             NM_003000.2(SDHB):c.143A>T (p.Asp48Val)     SDHB
# 2158       NM_001020658.1(PUM1):c.3439C>T (p.Arg1147Trp)     PUM1
# 2159       NM_001020658.1(PUM1):c.3415C>T (p.Arg1139Trp)     PUM1
# 2160       NM_001020658.1(PUM1):c.3103A>T (p.Thr1035Ser)     PUM1
# 3175            NM_002016.1(FLG):c.2143C>T (p.Gln715Ter)      FLG
# 3439            NM_003001.3(SDHC):c.397C>T (p.Arg133Ter)     SDHC
# 3575             NM_000261.1(MYOC):c.136C>T (p.Arg46Ter)     MYOC
# 3983       NM_000069.2(CACNA1S):c.3716G>A (p.Arg1239His)  CACNA1S
# ...
