# %%
import pandas as pd
import numpy as np
import os
import argparse 
import time
import gc

# %%
in_f = '/home/vpt/data/dbNSFP/dbNSFP4.0a/dbNSFP4.0a.txt.gz'
#out_f = '/home/vpt/data/benchmark/Jinchen2018/jinchen_dbNSFP40a.tsv'
out_f = '/home/vpt/data/benchmark/Jinchen2018/test.tsv'

query_f = '/home/vpt/data/benchmark/Jinchen2018/supplementary-Table-S2-The-testing-missense-variants-of-benchmark-datasets.tsv'
size = 100000

# %%
def extract_rareVariants_from_dbNSFP(in_f, out_f, size, query):
    reader = pd.read_table(in_f, chunksize=size,na_values = '.')
    
    t0 = time.time()
    for k,chunk in enumerate(reader):
        minutes = (time.time()-t0)/float(60)
        if k&(k-1)==0:
            print 'processed %s*%s rows. Elapsed, %s minutes'%(k,size,minutes)
#        if k==1:
#            break

        chunk.index = chunk.hg19_chr.map(str) + '-' + chunk['hg19_pos(1-based)'].map(str) + '-' + chunk.ref.map(str) + '-' + chunk.alt.map(str)
        query_chunk = pd.merge(chunk,query,left_index = True, right_index= True, how = 'inner') 

        # keep variants with max_freq_observed under threshold  
        # ALSO exclude those with maximum freq = 0.0000 (only for sanity)

        if k==0:
            query_chunk.to_csv(out_f, index=True,sep='\t') 
        else:
            query_chunk.to_csv(out_f, index=True, header=False, mode='a',sep='\t')
        gc.collect()
    return(None)

# %%
query = pd.read_csv(query_f,sep = '\t')
query['Chr'] = query.Chr.str.strip('chr')
query.index = query.Chr.map(str) +'-' + query.Start.map(str) +'-' + query.Ref.map(str) +'-' + query.Alt.map(str)

# %%
chunk = pd.read_csv(in_f, na_values = '.',nrows = 1000000,sep = '\t',dtype={'hg19_pos(1-based)':str,'hg19_chr':str})
#chunk['hg19_pos(1-based)'].map()
#chunk.hg19_chr.map()
chunk.index = chunk.hg19_chr.map(str) + '-' + chunk['hg19_pos(1-based)'].map(str) + '-' + chunk.ref.map(str) + '-' + chunk.alt.map(str)
chunk.head()
# Out:
#              #chr  pos(1-based) ref alt aaref aaalt rs_dbSNP151 hg19_chr  \
# 1-65565-A-C     1         65565   A   C     M     L         NaN        1
# 1-65565-A-G     1         65565   A   G     M     V         NaN        1
# 1-65565-A-T     1         65565   A   T     M     L         NaN        1
# 1-65566-T-A     1         65566   T   A     M     K         NaN        1
# 1-65566-T-C     1         65566   T   C     M     T         NaN        1
#
#             hg19_pos(1-based)  hg18_chr            ...             \
# 1-65565-A-C             65565       1.0            ...
# 1-65565-A-G             65565       1.0            ...
# 1-65565-A-T             65565       1.0            ...
# 1-65566-T-A             65566       1.0            ...
# 1-65566-T-C             65566       1.0            ...
#
#              clinvar_review clinvar_hgvs clinvar_var_source clinvar_MedGen_id  \
# 1-65565-A-C             NaN          NaN                NaN               NaN
# 1-65565-A-G             NaN          NaN                NaN               NaN
# 1-65565-A-T             NaN          NaN                NaN               NaN
# 1-65566-T-A             NaN          NaN                NaN               NaN
# 1-65566-T-C             NaN          NaN                NaN               NaN
#
#             clinvar_OMIM_id clinvar_Orphanet_id Interpro_domain GTEx_V7_gene  \
# 1-65565-A-C             NaN                 NaN             NaN          NaN
# 1-65565-A-G             NaN                 NaN             NaN          NaN
# 1-65565-A-T             NaN                 NaN             NaN          NaN
# 1-65566-T-A             NaN                 NaN             NaN          NaN
# 1-65566-T-C             NaN                 NaN             NaN          NaN
#
#             GTEx_V7_tissue Geuvadis_eQTL_target_gene
# 1-65565-A-C            NaN                       NaN
# 1-65565-A-G            NaN                       NaN
# 1-65565-A-T            NaN                       NaN
# 1-65566-T-A            NaN                       NaN
# 1-65566-T-C            NaN                       NaN
#
# [5 rows x 376 columns]

# %%
query_chunk = pd.merge(chunk,query,left_index = True, right_index= True, how = 'inner')
query_chunk.shape
# Out:
# (110, 384)

# %%
query_chunk = pd.merge(chunk,query,left_on = ['hg19_chr','hg19_pos(1-based)','ref', 'alt'],
                       right_on= ['Chr','Start','Ref','Alt'], how = 'inner') 
query_chunk.shape
# Out:
# (0, 384)

# %%
chunk.head()
# Out:
#              #chr  pos(1-based) ref alt aaref aaalt rs_dbSNP151 hg19_chr  \
# 1-65565-A-C     1         65565   A   C     M     L         NaN        1
# 1-65565-A-G     1         65565   A   G     M     V         NaN        1
# 1-65565-A-T     1         65565   A   T     M     L         NaN        1
# 1-65566-T-A     1         65566   T   A     M     K         NaN        1
# 1-65566-T-C     1         65566   T   C     M     T         NaN        1
#
#             hg19_pos(1-based)  hg18_chr            ...             \
# 1-65565-A-C             65565       1.0            ...
# 1-65565-A-G             65565       1.0            ...
# 1-65565-A-T             65565       1.0            ...
# 1-65566-T-A             65566       1.0            ...
# 1-65566-T-C             65566       1.0            ...
#
#              clinvar_review clinvar_hgvs clinvar_var_source clinvar_MedGen_id  \
# 1-65565-A-C             NaN          NaN                NaN               NaN
# 1-65565-A-G             NaN          NaN                NaN               NaN
# 1-65565-A-T             NaN          NaN                NaN               NaN
# 1-65566-T-A             NaN          NaN                NaN               NaN
# 1-65566-T-C             NaN          NaN                NaN               NaN
#
#             clinvar_OMIM_id clinvar_Orphanet_id Interpro_domain GTEx_V7_gene  \
# 1-65565-A-C             NaN                 NaN             NaN          NaN
# 1-65565-A-G             NaN                 NaN             NaN          NaN
# 1-65565-A-T             NaN                 NaN             NaN          NaN
# 1-65566-T-A             NaN                 NaN             NaN          NaN
# 1-65566-T-C             NaN                 NaN             NaN          NaN
#
#             GTEx_V7_tissue Geuvadis_eQTL_target_gene
# 1-65565-A-C            NaN                       NaN
# 1-65565-A-G            NaN                       NaN
# 1-65565-A-T            NaN                       NaN
# 1-65566-T-A            NaN                       NaN
# 1-65566-T-C            NaN                       NaN
#
# [5 rows x 376 columns]

# %%
extract_rareVariants_from_dbNSFP(in_f = in_f,out_f = out_f,size = size,query = query)
# Out:
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (6,11,26,32,36,39,42,44,45,47,52,57,59,60,62,63,66,80,82,83,84,85,87,92,94,95,96,97,98,99,100,225,298,364,365,366,367,368,369,370,371,372,373,374,375) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (11,26,31,32,36,38,39,42,44,45,47,50,52,54,55,56,57,59,60,62,63,65,66,70,73,77,82,83,84,85,87,92,95,96,97,98,99,100,225,298,364,365,366,367,368,369,370,371,372,373,374,375) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed 0*100000 rows. Elapsed, 0.0840011318525 minutes
# processed 1*100000 rows. Elapsed, 0.179741251469 minutes
# processed 2*100000 rows. Elapsed, 0.2710019509 minutes
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (11,26,27,32,36,39,41,42,44,45,47,50,52,56,57,59,60,62,63,66,70,73,77,80,82,83,84,85,87,91,92,94,95,96,97,98,99,100,112,225,298,364,365,366,367,368,369,370,371,372,373,374,375) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (11,26,31,36,39,42,45,52,57,60,63,66,80,85,87,92,95,96,97,98,99,100,225,298,364,365,366,367,368,369,370,371,372,373,374,375) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# processed 4*100000 rows. Elapsed, 0.454231266181 minutes
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (11,26,36,39,42,45,50,52,57,60,62,63,66,85,87,92,95,96,97,98,99,100,225,298,364,365,366,367,368,369,371,372,373,374,375) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (11,26,36,39,42,44,45,47,50,52,57,59,60,62,63,66,82,83,84,85,87,92,94,95,96,97,98,99,100,225,298,364,365,366,367,368,369,370,371,372,373,374,375) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (11,26,36,39,42,44,45,47,50,52,57,59,60,62,63,66,82,83,84,85,87,92,95,96,97,98,99,100,225,298,364,365,366,367,368,369,370,371,372,373,374,375) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2883: DtypeWarning: Columns (11,16,17,21,26,32,36,38,39,41,42,44,45,47,50,52,54,55,56,57,59,60,62,63,65,66,70,73,77,82,83,84,85,87,91,92,94,95,96,97,98,99,100,108,109,112,150,225,298,364,365,366,367,368,369,371,372,373,374) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/common.pyc in <lambda>(self)
#      71
#      72 if not compat.PY3:
# ---> 73     BaseIterator.next = lambda self: self.__next__()
#      74
#      75
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __next__(self)
#    1040     def __next__(self):
#    1041         try:
# -> 1042             return self.get_chunk()
#    1043         except StopIteration:
#    1044             self.close()
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in get_chunk(self, size)
#    1104                 raise StopIteration
#    1105             size = min(size, self.nrows - self._currow)
# -> 1106         return self.read(nrows=size)
#    1107
#    1108
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/parsers.so in pandas._libs.parsers.TextReader.read()
#
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/parsers.so in pandas._libs.parsers.TextReader._read_low_memory()
#
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/parsers.so in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/parsers.so in pandas._libs.parsers.TextReader._convert_column_data()
#
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/parsers.so in pandas._libs.parsers.TextReader._convert_tokens()
#
# /usr/local/lib/python2.7/dist-packages/pandas/_libs/parsers.so in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/dtypes/common.pyc in is_integer_dtype(arr_or_dtype)
#     775
#     776
# --> 777 def is_integer_dtype(arr_or_dtype):
#     778     """
#     779     Check whether the provided array or dtype is of an integer dtype.
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('/home/vpt/data/benchmark/Jinchen2018/test.tsv',sep ='\t',index_col=0)

# %%
df.head()
# Out:
#                #chr  pos(1-based) ref alt aaref aaalt  rs_dbSNP151  hg19_chr  \
# 1-2238024-C-G     1       2306585   C   G     D     E  rs750838146         1
# 1-2343941-T-C     1       2412502   T   C     M     V  rs886041314         1
# 1-3328187-C-T     1       3411623   C   T     P     S  rs188908415         1
# 1-3328445-G-A     1       3411881   G   A     V     I  rs150395260         1
# 1-3329213-G-A     1       3412649   G   A     G     S  rs201904226         1
#
#                hg19_pos(1-based)  hg18_chr     ...      GTEx_V7_tissue  \
# 1-2238024-C-G            2238024       1.0     ...                 NaN
# 1-2343941-T-C            2343941       1.0     ...                 NaN
# 1-3328187-C-T            3328187       1.0     ...                 NaN
# 1-3328445-G-A            3328445       1.0     ...                 NaN
# 1-3329213-G-A            3329213       1.0     ...                 NaN
#
#               Geuvadis_eQTL_target_gene Data source Chr    Start      End Ref  \
# 1-2238024-C-G                       NaN     ClinVar   1  2238024  2238024   C
# 1-2343941-T-C                       NaN     ClinVar   1  2343941  2343941   T
# 1-3328187-C-T                       NaN     ClinVar   1  3328187  3328187   C
# 1-3328445-G-A                       NaN     ClinVar   1  3328445  3328445   G
# 1-3329213-G-A                       NaN     ClinVar   1  3329213  3329213   G
#
#               Alt Gene_symbol       Label
# 1-2238024-C-G   G         SKI      Benign
# 1-2343941-T-C   C       PEX10  Pathogenic
# 1-3328187-C-T   T      PRDM16      Benign
# 1-3328445-G-A   A      PRDM16      Benign
# 1-3329213-G-A   A      PRDM16      Benign
#
# [5 rows x 384 columns]
